# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # *About the data*
#
# The dataset contains information about a group of test subjects and their sleep patterns. Each test subject is identified by a unique "Subject ID" and their age and gender are also recorded. The "Bedtime" and "Wakeup time" features indicate when each subject goes to bed and wakes up each day, and the "Sleep duration" feature records the total amount of time each subject slept in hours. The "Sleep efficiency" feature is a measure of the proportion of time spent in bed that is actually spent asleep. The "REM sleep percentage", "Deep sleep percentage", and "Light sleep percentage" features indicate the amount of time each subject spent in each stage of sleep. The "Awakenings" feature records the number of times each subject wakes up during the night. Additionally, the dataset includes information about each subject's caffeine and alcohol consumption in the 24 hours prior to bedtime, their smoking status, and their exercise frequency.

# %%
df = pd.read_csv('/Users/daniboy/Desktop/Platzi_Courses/Git_Github/Sleep_Efficiency/Sleep_Efficiency.csv')
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      452 non-null    int64
#  1   Age                     452 non-null    int64
#  2   Gender                  452 non-null    object
#  3   Bedtime                 452 non-null    object
#  4   Wakeup time             452 non-null    object
#  5   Sleep duration          452 non-null    float64
#  6   Sleep efficiency        452 non-null    float64
#  7   REM sleep percentage    452 non-null    int64
#  8   Deep sleep percentage   452 non-null    int64
#  9   Light sleep percentage  452 non-null    int64
#  10  Awakenings              432 non-null    float64
#  11  Caffeine consumption    427 non-null    float64
#  12  Alcohol consumption     438 non-null    float64
#  13  Smoking status          452 non-null    object
#  14  Exercise frequency      446 non-null    float64
# dtypes: float64(6), int64(5), object(4)
# memory usage: 53.1+ KB
#                ID         Age  Sleep duration  Sleep efficiency
# count  452.000000  452.000000      452.000000        452.000000  \
# mean   226.500000   40.285398        7.465708          0.788916
# std    130.625419   13.172250        0.866625          0.135237
# min      1.000000    9.000000        5.000000          0.500000
# 25%    113.750000   29.000000        7.000000          0.697500
# 50%    226.500000   40.000000        7.500000          0.820000
# 75%    339.250000   52.000000        8.000000          0.900000
# max    452.000000   69.000000       10.000000          0.990000
#
#        REM sleep percentage  Deep sleep percentage  Light sleep percentage
# count            452.000000             452.000000              452.000000  \
# mean              22.615044              52.823009               24.561947
# std                3.525963              15.654235               15.313665
# min               15.000000              18.000000                7.000000
# 25%               20.000000              48.250000               15.000000
# 50%               22.000000              58.000000               18.000000
# 75%               25.000000              63.000000               32.500000
# max               30.000000              75.000000               63.000000
#
#        Awakenings  Caffeine consumption  Alcohol consumption
# count  432.000000            427.000000           438.000000  \
# mean     1.641204             23.653396             1.173516
# std      1.356762             30.202785             1.621377
# min      0.000000              0.000000             0.000000
# 25%      1.000000              0.000000             0.000000
# 50%      1.000000             25.000000             0.000000
# 75%      3.000000             50.000000             2.000000
# max      4.000000            200.000000             5.000000
#
#        Exercise frequency
# count          446.000000
# mean             1.791480
# std              1.428134
# min              0.000000
# 25%              0.000000
# 50%              2.000000
# 75%              3.000000
# max              5.000000

# %%
df.head()
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0  \
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage
# 0              0.88                    18                     70  \
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption
# 0                      12         0.0                   0.0  \
# 1                      53         3.0                   0.0
# 2                      10         1.0                   0.0
# 3                      52         3.0                  50.0
# 4                      18         3.0                   0.0
#
#    Alcohol consumption Smoking status  Exercise frequency
# 0                  0.0            Yes                 3.0
# 1                  3.0            Yes                 3.0
# 2                  0.0             No                 3.0
# 3                  5.0            Yes                 1.0
# 4                  3.0             No                 3.0

# %%
df.head()
plt.figure(figsize=[12,6])
sns.pairplot(data=df)

# %% [markdown]
# ### with the naked eye, i can see some correlations and one **negative linear regresion**

# %%
plt.subplot(1,2,1)
plt.plot(x= 'Deep sleep percentage', y='Light sleep percentage')
plt.figure(figsize=[10,5])
#sns.scatterplot(data=df, x='Deep sleep percentage', y='Light sleep percentage')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 plt.subplot(1,2,1)
# ----> 2 plt.plot(x= df['Deep sleep percentage'], y=df['Light sleep percentage'])
#       3 plt.figure(figsize=[10,5])
#       4 #sns.scatterplot(data=df, x='Deep sleep percentage', y='Light sleep percentage')
#
# File ~/miniconda3/envs/ML/lib/python3.11/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/miniconda3/envs/ML/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~/miniconda3/envs/ML/lib/python3.11/site-packages/matplotlib/axes/_base.py:246, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     244 for pos_only in "xy":
#     245     if pos_only in kwargs:
# --> 246         raise _api.kwarg_error(self.command, pos_only)
#     248 if not args:
#     249     return
#
# TypeError: plot() got an unexpected keyword argument 'x'

# %% [markdown]
# I tried to plot to graphics in one plot, but i couldn't, so I asked it to chatgpt:
# '''como crear 2 graficas diferentes en un mismo panel con matplotlib y Seaborn de un dataframe'''

# %%
# Crear un subplot con dos gráficas en una fila
fig, ax = plt.subplots(ncols=2, figsize=(10, 5))

# Graficar la primera variable en el primer subplot con Seaborn
sns.scatterplot(data=df, x= 'Light sleep percentage', y='Deep sleep percentage', ax=ax[0])

# Agregar título y etiquetas de los ejes
ax[0].set_title('correlacion!!', c='blue')
ax[0].set_xlabel('Light sleep percentage')
ax[0].set_ylabel('Deep sleep percentage')


# Graficar la segunda variable en el segundo subplot con Seaborn
sns.scatterplot(data=df, x='Deep sleep percentage', y='Sleep efficiency', ax=ax[1])

# Agregar título y etiquetas de los ejes
ax[1].set_title('Deep sleep percentage vs Sleep efficiency')
ax[1].set_xlabel('Deep sleep percentage')
ax[1].set_ylabel('Sleep efficiency')

# Mostrar la figura
plt.show()

# %% [markdown]
# I asked to an AI the next : en lenguaje de Markdown, con un tipo de letra y color bonitos escribe lo siguiente: "I created a new branch trying to do my first linear regression just in case that it doesn't work. If it works good, I'll merge it"
# This was the answer:
# # <span style="color:cornflowerblue">I created a new branch trying to do my first linear regression just in case that it doesn't work. If it works good, I'll merge it.</span>

# %% [markdown]
# I can transform then human lenguage to markdown or python with their libraries without learning to code, just learning the basis to give the correct prompts!! It's amazing. This tool will save me a lot of time. Instead wasting it to learn how to code with a specific lenguage, I can improve my prompt engineering with the new Platzi course and practicing a lot

# %%
sns.scatterplot(data=df, x='Sleep duration', y='Sleep efficiency', hue='Smoking status')
# Out:
# <Axes: xlabel='Sleep duration', ylabel='Sleep efficiency'>

# %% [markdown]
# ## A mayor luz durante la noche, menor sueño profundo!! Parece ser la unica regresión lineal simple, por lo que puedo asegurar que una mejor calidad de sueño

# %% [markdown]
# I can select specifyc lines and columns with loc

# %%
sleep_rem = df.loc[::2, ['Sleep duration', 'REM sleep percentage']]
sleep_rem
# Out:
#      Sleep duration  REM sleep percentage
# 0               6.0                    18
# 2               8.0                    20
# 4               8.0                    27
# 6               6.0                    28
# 8               6.0                    28
# ..              ...                   ...
# 442             7.0                    23
# 444             7.5                    24
# 446             7.0                    15
# 448             6.0                    28
# 450             7.0                    18
#
# [226 rows x 2 columns]

# %%
sns.scatterplot(data=sleep_rem, x='Sleep duration', y= 'REM sleep percentage')
# Out:
# <Axes: xlabel='Sleep duration', ylabel='REM sleep percentage'>

# %% [markdown]
# there seems to be no correlation between these variables. The duration of your sleep does not affect your REM sleep I think. Obviously, if we are talking about quantities, a longer sleep duration, a longer REM sleep time.

# %% [markdown]
# ### I can get a lot of insights with this dataset! I'll be practicing with pandas, sklearn, and some things in the next few days

# %%
sns.scatterplot(data=df, x='Sleep duration', y='Sleep efficiency', hue='Smoking status')
# Out:
# <Axes: xlabel='Sleep duration', ylabel='Sleep efficiency'>

# %% [markdown]
# As we can see, being a smoker person affects directly to your sleep efficiency!

# %%
sns.scatterplot(data=df, x='Sleep duration', y='REM sleep percentage', hue='Smoking status')
# Out:
# <Axes: xlabel='Sleep duration', ylabel='REM sleep percentage'>

# %%
sns.scatterplot(data=df, x='Sleep duration', y='Sleep efficiency', hue='Awakenings', palette='inferno')
# Out:
# <Axes: xlabel='Sleep duration', ylabel='Sleep efficiency'>

# %% [markdown]
# This data is amazing! the people who use to awake less, tend to sleep better 🤯, it might sound obvious, but seeing in the data makes me confirm this fact.

# %%
df.head()
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0  \
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage
# 0              0.88                    18                     70  \
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption
# 0                      12         0.0                   0.0  \
# 1                      53         3.0                   0.0
# 2                      10         1.0                   0.0
# 3                      52         3.0                  50.0
# 4                      18         3.0                   0.0
#
#    Alcohol consumption Smoking status  Exercise frequency
# 0                  0.0            Yes                 3.0
# 1                  3.0            Yes                 3.0
# 2                  0.0             No                 3.0
# 3                  5.0            Yes                 1.0
# 4                  3.0             No                 3.0

# %%
pairplot_important_columns = df.loc[::1, ['Age', 'Gender', 'Sleep duration', 'Sleep efficiency','Smoking status','Exercise frequency']]
pairplot_important_columns.head()
# Out:
#    Age  Gender  Sleep duration  Sleep efficiency Smoking status
# 0   65  Female             6.0              0.88            Yes  \
# 1   69    Male             7.0              0.66            Yes
# 2   40  Female             8.0              0.89             No
# 3   40  Female             6.0              0.51            Yes
# 4   57    Male             8.0              0.76             No
#
#    Exercise frequency
# 0                 3.0
# 1                 3.0
# 2                 3.0
# 3                 1.0
# 4                 3.0

# %%
pairplot_important_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 452 non-null    int64
#  1   Gender              452 non-null    object
#  2   Sleep duration      452 non-null    float64
#  3   Sleep efficiency    452 non-null    float64
#  4   Smoking status      452 non-null    object
#  5   Exercise frequency  446 non-null    float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 21.3+ KB

# %%
sns.pairplot(pairplot_important_columns)

# %%
sns.scatterplot(data=pairplot_important_columns, x='Age', y='Exercise frequency', hue='Gender', palette='inferno')
# Out:
# <Axes: xlabel='Age', ylabel='Exercise frequency'>

# %% [markdown]
# Why do men tend to be in the middle and women at extremes on the exercise frequency? Passing the 40 years, the comparision seems to be equal. another insight seems to be that women either do a lot of exercise, or do not

# %%
sns.scatterplot(data=pairplot_important_columns, x='Exercise frequency', y='Sleep efficiency', hue='Smoking status', palette='inferno')
# Out:
# <Axes: xlabel='Exercise frequency', ylabel='Sleep efficiency'>

# %% [markdown]
# There's no smokers who tend to do a high exercise and most of them, the sleep efficiency is poor

# %%
df.head()
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0  \
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage
# 0              0.88                    18                     70  \
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption
# 0                      12         0.0                   0.0  \
# 1                      53         3.0                   0.0
# 2                      10         1.0                   0.0
# 3                      52         3.0                  50.0
# 4                      18         3.0                   0.0
#
#    Alcohol consumption Smoking status  Exercise frequency
# 0                  0.0            Yes                 3.0
# 1                  3.0            Yes                 3.0
# 2                  0.0             No                 3.0
# 3                  5.0            Yes                 1.0
# 4                  3.0             No                 3.0

# %%
sns.displot(data=df, x='Awakenings', hue='Gender' )
plt.show()

# %% [markdown]
# men wake up more at night than women

# %%
df.head()
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0  \
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage
# 0              0.88                    18                     70  \
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption
# 0                      12         0.0                   0.0  \
# 1                      53         3.0                   0.0
# 2                      10         1.0                   0.0
# 3                      52         3.0                  50.0
# 4                      18         3.0                   0.0
#
#    Alcohol consumption Smoking status  Exercise frequency
# 0                  0.0            Yes                 3.0
# 1                  3.0            Yes                 3.0
# 2                  0.0             No                 3.0
# 3                  5.0            Yes                 1.0
# 4                  3.0             No                 3.0

# %%
df_2 = df.loc[50:100:2, ['Age', 'Gender', 'Sleep duration', 'Sleep efficiency','Smoking status','Exercise frequency']]
df_2.head()
# Out:
#     Age  Gender  Sleep duration  Sleep efficiency Smoking status
# 50   29  Female             7.0              0.71             No  \
# 52    9  Female             8.5              0.52             No
# 54   18    Male             7.5              0.84             No
# 56   54    Male             8.0              0.99             No
# 58   34  Female             7.0              0.71             No
#
#     Exercise frequency
# 50                 2.0
# 52                 0.0
# 54                 3.0
# 56                 3.0
# 58                 1.0
